# %%
import pickle
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from pprint import pprint

# %%
file = open('../data/filtered_data.pickle', 'rb')
data = pickle.load(file)
file.close()

data.reset_index(drop=True, inplace=True)

data.head()
# Out:
#          id         submitter                                    authors  \
# 0   704.002   Patrick Roudeau  The BABAR Collaboration, B. Aubert, et al
# 1  704.2033  Anwar Shiekh Dr.                                A.Y. Shiekh
# 2  704.2088   Shimul Akhanjee                            Shimul Akhanjee
# 3   704.211   Ekkehard Kruger                          Ekkehard Kr\"uger
# 4  704.2977  Kostya Trachenko        Kostya Trachenko and Vadim Brazhkin
#
#                                                title  \
# 0  Measurement of the Hadronic Form Factor in D0 ...
# 1  The Quantum Interference Computer: an experime...
# 2  Exact longitudinal plasmon dispersion relation...
# 3  Stability of the superconducting state in YBa_...
# 4  Liquid elasticity length and universal dynamic...
#
#                                             comments  \
# 0  21 pages, 13 postscript figures, submitted to ...
# 1                                  6 pages, 1 figure
# ...

# %%
df = pd.read_csv("../data/cnn_workloads/nn1000_n10.csv")
