# %%
import pandas as pd

# %%
df = pd.read_csv("stats.csv")

mean_columns = [col for col in df.columns if "mean" in col or "filename" in col]

df_mean = df[mean_columns]
df_mean
# Out:
#                     filename  distances_title_vector_mean  \
# 0   cv0_05_num20_prob0_1.csv                     1.210421
# 1   cv0_05_num20_prob0_3.csv                     1.179525
# 2   cv0_05_num20_prob0_5.csv                     1.138146
# 3   cv0_05_num20_prob1_0.csv                     1.080025
# 4    cv0_1_num10_prob0_1.csv                     1.296962
# 5    cv0_1_num10_prob0_3.csv                     1.295132
# 6    cv0_1_num10_prob0_5.csv                     1.216549
# 7    cv0_1_num10_prob1_0.csv                     1.208506
# 8     cv0_3_num5_prob0_1.csv                     1.249928
# 9     cv0_3_num5_prob0_3.csv                     1.155603
# 10    cv0_3_num5_prob0_5.csv                     1.184324
# 11    cv0_3_num5_prob1_0.csv                     1.102847
# 12    cv0_5_num3_prob0_1.csv                     1.217745
# 13    cv0_5_num3_prob0_3.csv                     1.288956
# 14    cv0_5_num3_prob0_5.csv                     1.183219
# 15    cv0_5_num3_prob1_0.csv                     1.042452
# 16        small_workload.csv                     1.223869
# 17       small_workload2.csv                     1.192671
#
#     distances_hybrid_mean  distances_weighted_hybrid_mean  \
# 0                1.213111                        1.228738
# 1                1.179975                        1.190861
# 2                1.234872                        1.251081
# 3                1.190437                        1.155670
# 4                1.293779                        1.305348
# 5                1.320508                        1.325553
# 6                1.222805                        1.218526
# 7                1.209314                        1.235564
# 8                1.283956                        1.282181
# 9                1.198860                        1.188357
# 10               1.202640                        1.187141
# 11               1.119016                        1.185158
# 12               1.221519                        1.250891
# 13               1.310138                        1.314700
# 14               1.192858                        1.197473
# 15               1.103075                        1.119798
# 16               1.238460                        1.246985
# 17               1.232911                        1.215076
#
#     accuracy_title_vector_mean  accuracy_hybrid_mean  \
# 0                     0.010000              0.010000
# 1                     0.005000              0.005000
# 2                     0.075000              0.055000
# 3                     0.010000              0.000000
# 4                     0.010000              0.010000
# 5                     0.005000              0.005000
# 6                     0.010000              0.010000
# 7                     0.045000              0.040000
# 8                     0.015000              0.015000
# 9                     0.005000              0.005000
# 10                    0.020000              0.025000
# 11                    0.025000              0.025000
# 12                    0.025000              0.025000
# 13                    0.005000              0.005000
# 14                    0.035000              0.035000
# 15                    0.070000              0.060000
# 16                    0.028571              0.014286
# 17                    0.018750              0.018750
#
#     accuracy_weighted_hybrid_mean  percent_include_title_vector_mean  \
# 0                        0.010000                           0.020000
# 1                        0.005000                           0.045000
# 2                        0.055000                           0.310000
# 3                        0.000000                           0.195000
# 4                        0.010000                           0.045000
# 5                        0.005000                           0.070000
# 6                        0.010000                           0.030000
# 7                        0.040000                           0.125000
# 8                        0.015000                           0.035000
# 9                        0.005000                           0.080000
# 10                       0.020000                           0.065000
# 11                       0.025000                           0.175000
# 12                       0.025000                           0.070000
# 13                       0.005000                           0.015000
# 14                       0.035000                           0.085000
# 15                       0.060000                           0.215000
# 16                       0.014286                           0.085714
# 17                       0.018750                           0.056250
#
#     percent_include_hybrid_mean  percent_include_weighted_hybrid_mean
# 0                      0.035000                              0.015000
# 1                      0.040000                              0.030000
# 2                      0.260000                              0.210000
# 3                      0.115000                              0.115000
# 4                      0.025000                              0.025000
# 5                      0.040000                              0.045000
# 6                      0.020000                              0.015000
# 7                      0.110000                              0.105000
# 8                      0.030000                              0.030000
# 9                      0.040000                              0.050000
# 10                     0.040000                              0.040000
# 11                     0.175000                              0.125000
# 12                     0.070000                              0.065000
# 13                     0.010000                              0.015000
# 14                     0.070000                              0.055000
# 15                     0.140000                              0.130000
# 16                     0.071429                              0.057143
# 17                     0.050000                              0.050000
